# %% [markdown]
# # ⚛️ Single Qubit Gates Demonstration
#
# This Jupyter Notebook shows how to apply basic **single qubit gates** using Qiskit.
#
# You will learn how to:
# - Apply gates like **Hadamard** and **Pauli-X**
# - Visualize the circuit
# - Simulate and measure the output
#
# ---

# %% [markdown]
# # Single Qubit Implementation

# %% [markdown]
# ## imports

# %%
# 📚 Import required libraries
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram

# %% [markdown]
# ## circiut building

# %%
# ⚙️ Create a quantum circuit with 1 qubit and 1 classical bit
qc = QuantumCircuit(1, 1)
# Apply a Hadamard gate to create a superposition
qc.h(0)

# Measure the qubit into the classical bit
qc.measure(0, 0)

# 🖼️ Draw the circuit diagram
qc.draw("mpl")

# %% [markdown]
# ## running on simulator

# %%
job = AerSimulator()
backend = job.run(qc)
# Get the simulation result
job_result = backend.result()
# Get the simulation result
counts = job_result.get_counts(qc)
# 📊 Plot a histogram of results
plot_histogram(counts)

# %% [markdown]
# ## ✅ Conclusion
#
# - Demonstrated single-qubit gate operations using Qiskit.
# - Visualized circuit steps and measurement results.
# - Forms the basis for more advanced quantum circuits.
#
# ---
# **Made with ❤️ using Qiskit**
